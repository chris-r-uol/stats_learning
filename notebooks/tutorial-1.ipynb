# %% [markdown]
# # Tutorial 1 — Descriptive Statistics and Data VisualisationThis tutorial covers how to describe a set of data. You will identify thetype of data, calculate summary statistics, draw two charts, and find anoutlier.Questions and answer checking: https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1This file gives you the questions and the data. Work out each answerhere, then enter it on the website to check it.

# %% [markdown]
# ## Before you startDo the calculations in Excel, R or Python. Then enter each answer to checkit.Some questions have long tables. These ask for a few rows only. The fulltable is in the solution.

# %% [markdown]
# ## Setup

# %%
import numpy as npimport pandas as pdimport matplotlib.pyplot as pltfrom scipy import statsfrom pathlib import Path# Find data/csv from wherever this notebook is run.DATA = next(p / "data" / "csv" for p in [Path.cwd(), *Path.cwd().parents]            if (p / "data" / "csv").is_dir())travel_times = pd.read_csv(DATA / "travel-times.csv")travel_times.head()

# %% [markdown]
# ## Question 1 — Types of dataData can be **continuous**, **discrete**, **grouped**, **ordinal** or**nominal**. Choose the type for each example below.A reminder of the five types:- **Continuous** — any value in a range, including fractions (rainfall in mm)- **Discrete** — whole numbers only (number of bicycles sold)- **Grouped** — numbers sorted into bands (income of £20–30k)- **Ordinal** — categories with an order (poor / fair / good)- **Nominal** — categories with no order (paint colours)[Check your answers](https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1#t1-q1)

# %% [markdown]
# **1.** Speed of a moving vehicle over time.

# %% [markdown]
# **2.** Ranking of traffic congestion (high, medium, low).

# %% [markdown]
# **3.** Age range of drivers involved in accidents (18–25, 26–35, 36–45, 45+).

# %% [markdown]
# **4.** Vehicle types (car, lorry, bus, and so on).

# %% [markdown]
# **5.** Number of passengers on a bus.

# %% [markdown]
# ## Question 2 — Descriptive statisticsA survey recorded the time to travel between two locations. Use the datain **B4:B58** to calculate the statistics below.[Check your answers](https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1#t1-q2)

# %% [markdown]
# **1.** How many observations are in the data set?

# %% [markdown]
# **2.** What is the mean travel time? (minutes)

# %% [markdown]
# **3.** What is the median travel time? (minutes)

# %% [markdown]
# **4.** What is the mode? (minutes)

# %% [markdown]
# **5.** Which function gives the standard deviation of this data?

# %% [markdown]
# **6.** What is the standard deviation? (minutes)

# %% [markdown]
# **7.** What is the variance?

# %% [markdown]
# **8.** What is the skewness?

# %% [markdown]
# **9.** Give the first, second and third quartiles.

# %% [markdown]
# ## Question 3 — HistogramThe counts are on the **T1 Histogram Guide** sheet. Draw a histogram oftravel time using **relative frequency density** and a class width of 5.Add three columns to your sheet:- Relative frequency = count in bin ÷ total count- Relative frequency density = relative frequency ÷ class width- Cumulative relative frequency = running total of the relative frequenciesThen complete the three rows below to check your columns.[Check your answers](https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1#t1-q3)

# %% [markdown]
# **1.** Complete these three rows of your table.

# %% [markdown]
# **2.** Which column do you plot to draw the histogram?

# %% [markdown]
# ## Question 4 — Cumulative relative frequency plotDraw a cumulative relative frequency plot of travel time, using a classwidth of 5. You already have the column from Question 3.[Check your answers](https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1#t1-q4)

# %% [markdown]
# **1.** What should the last point on this plot equal?

# %% [markdown]
# **2.** Reading from your plot, what share of journeys took 20 minutes or less?

# %% [markdown]
# ## Question 5 — OutliersUse the histogram and the cumulative frequency plot to find the outliers.How many are there, and what are their values?[Check your answers](https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1#t1-q5)

# %% [markdown]
# **1.** How many outliers are in the data set?

# %% [markdown]
# **2.** What is its value? (minutes)

# %% [markdown]
# **3.** What should you do with the outlier?

# %% [markdown]
# ## Question 6 — The effect of removing the outlierRepeat Question 2 with the outlier removed. Then compare the two sets ofresults. One value out of 55 changes some statistics a lot and othersvery little.[Check your answers](https://chris-r-uol.github.io/stats_learning/tutorial.html?t=1#t1-q6)

# %% [markdown]
# **1.** Mean, with the outlier removed. (minutes)

# %% [markdown]
# **2.** Standard deviation, with the outlier removed. (minutes)

# %% [markdown]
# **3.** Skewness, with the outlier removed.

# %% [markdown]
# **4.** Which statistic changed *most* when the outlier was removed?

# %% [markdown]
# **5.** In two or three sentences, explain what this comparison shows abouthandling outliers. Write it for a colleague who does not usestatistics.
